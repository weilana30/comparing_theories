# %%
#histogram distribution of number of atoms
import pandas as pd
import seaborn as sns

df = pd.read_csv("/home/aweiland/comparing_theories/5k_mol_stats.csv")
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  mol_id  \
# 0           0             0               0                 0    2192
# 1           1             1               1                 1    2194
# 2           2             2               2                 2    2198
# 3           3             3               3                 3    2202
# 4           4             4               4                 4    2203
#
#    atom_index  Shift  atom_type  num_atoms  xtb_rmsd  ...  xtb_runtime  \
# 0           0  108.4          6         57  0.567481  ...      313.008
# 1           0   12.9          6         27  0.145308  ...      206.791
# 2           0  144.8          6         48  0.121894  ...      129.533
# 3           1   69.4          6         40  0.200460  ...      224.729
# 4           1   69.0          6         29  0.197792  ...      159.481
#
#    egret_runtime  egret_rmsd  egret_time  uma_time  uma_rmsd  r2scan_time  \
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

sns.set_theme(style="darkgrid")

fig = plt.figure(figsize=(12, 8))
gs = fig.add_gridspec(2, 2, height_ratios=[1, 1])

ax1 = fig.add_subplot(gs[0, :])
sns.histplot(data=df, x="num_atoms", binwidth = 3, color ="orange", ax=ax1)
ax1.set_title("Distribution of Total Atoms")
ax1.set_xlabel("Total Atoms")
ax1.set_ylabel("Count")
ax1.set_xticks(np.arange(0, 175, 10))


plt.show()

# %%
df.shape
# Out:
# (5138, 21)
