# %%
from ase.io import Trajectory
file = "/home/aweiland/comparing_theories/egret/egret_benchmark/outputs/0.005/mol_10009028/opt.traj"

traj = Trajectory(file)
atoms = traj[-1]

print(f"Force: \n{atoms.get_forces()}\n")
print(f"Energy: \n{atoms.get_potential_energy()}\n")
print(f"Positions: \n {atoms.get_positions()}\n")
print(f"Symbols: \n{atoms.get_chemical_symbols()}")
# Out:
# Force:
# [[ 1.62069204e-03 -1.21952086e-03 -1.34336846e-03]
#  [ 2.67129133e-03 -4.34749872e-04 -7.28276541e-04]
#  [ 3.04812101e-03  1.03003967e-03 -2.13161746e-03]
#  [ 2.99060023e-03 -9.15870775e-04  1.31717328e-03]
#  [-1.17428836e-03  1.38628355e-03  2.02536968e-03]
#  [-4.07485724e-04 -1.47216649e-03  7.36183768e-04]
#  [-1.61029811e-03  6.31639702e-04  6.77536766e-04]
#  [-3.82677555e-04  2.30882483e-04 -1.16797989e-03]
#  [ 2.29399915e-03  2.32818071e-03  1.58336341e-03]
#  [ 1.02501655e-03 -2.56654496e-03 -8.11455607e-04]
#  [ 1.85449581e-03  1.46615688e-03  1.79596875e-03]
#  [-2.98387360e-04  1.10905766e-03 -1.23097775e-03]
#  [ 7.99656390e-04 -1.21413572e-03 -2.25229858e-04]
#  [-1.72239592e-03 -1.02820103e-03  1.03432641e-03]
#  [-4.15990422e-03  1.15300856e-03  3.62217077e-04]
#  [-1.33877144e-03  1.24990222e-03  2.95039896e-03]
#  [-1.74946036e-03  2.15774300e-03 -3.54224864e-03]
#  [-1.88332061e-03  3.23918256e-05 -8.02997596e-04]
# ...
