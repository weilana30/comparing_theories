# %%
#converts csv will all mols to only ones in the 5k dataset
import pandas as pd

mol_stats = pd.read_csv("/home/aweiland/comparing_theories/mol_stats.csv")
fivek = pd.read_csv("/home/aweiland/comparing_theories/dft_geometries/5k_mol_ids.csv")

# %%
merged = pd.merge(fivek, mol_stats, on ="mol_id", how="inner")
merged.head()
# Out:
#    Unnamed: 0_x  Unnamed: 0.1_x  mol_id  atom_index  Shift  atom_type  \
# 0             0               0    2192           0  108.4          6
# 1            23              24    2194           0   12.9          6
# 2            30              31    2198           0  144.8          6
# 3            57              58    2202           1   69.4          6
# 4            69              70    2203           1   69.0          6
#
#    Unnamed: 0_y  Unnamed: 0.2  Unnamed: 0.1_y  Unnamed: 0.1.1  num_atoms  \
# 0          6327          6327            6327            6327         57
# 1          4792          4792            4792            4792         27
# 2           125           125             125             125         48
# 3          5338          5338            5338            5338         40
# 4          4112          4112            4112            4112         29
#
#    xtb_rmsd  aimnet_rmsd  xtb_runtime  egret_runtime  egret_rmsd
# ...

# %%
merged.to_csv("/home/aweiland/comparing_theories/5k_mol_stats.csv", index=False)
